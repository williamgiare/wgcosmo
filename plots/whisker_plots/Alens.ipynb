# %%
from __future__ import print_function
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import sys, os
sys.path.insert(0,os.path.realpath(os.path.join(os.getcwd(),'..')))
from getdist import plots, loadMCSamples, MCSamples
import getdist
import matplotlib.pyplot as plt
import IPython
from matplotlib import rc
import seaborn as sns
from scipy.constants import c
import pandas as pd
import numpy as np
from scipy.special import gamma, factorial, erfinv
import scipy.integrate as integrate
from scipy.integrate import quad
import matplotlib.pyplot as plt


plt.rcParams["axes.edgecolor"] = "0.15"
plt.rcParams["axes.linewidth"]  = "1.5"
plt.rcParams["ytick.labelsize"]  = "11"
plt.rcParams["xtick.labelsize"]  = "11"
plt.rcParams["axes.titlesize"]  = "11"
plt.rcParams["figure.figsize"] = [6,5]
plt.rcParams["figure.autolayout"] = True

y=[2,3,4,5,6]

ax1 = plt.subplot(111)
ax1.set_xlabel(r'$A_{L}$',fontsize = 15)
ax1.grid(linewidth=0.1)
#ax1.set_xlim(65,77)
ax1.set_xlim(0.7,1.3)
plt.yticks(np.arange(1, 7, 1.0))
ax1.set_ylim(0,5.5)

labels = [item.get_text() for item in ax1.get_yticklabels()]
labels[0]= 'Planck-PR3 (Plik)'
#labels[1]= 'Planck-PR3 (CamSpec)'
labels[1]= 'Planck-PR4 (CamSpec)'
labels[2]= 'Planck-PR4 (HiLLiPoP)'
labels[3]= 'ACT-DR4'
labels[4]= 'SPT-3G'
ax1.set_yticklabels(labels)




ax1.errorbar(1.180,1,xerr=0.065, alpha=1,color="darkred", marker='o',capsize=5, capthick=1,linestyle="none")
#ax1.errorbar(1.146,2,xerr=0.061, alpha=1,color="orangered", marker='o',capsize=5, capthick=1,linestyle="none")

ax1.errorbar(1.095 ,2, xerr=0.056, alpha=1,color="navy", marker='o',capsize=5, capthick=1,linestyle="none")
ax1.errorbar(1.039 ,3, xerr=0.052, alpha=1,color="darkgreen", marker='o',capsize=5, capthick=1,linestyle="none")

ax1.errorbar(1.01 ,4, xerr=0.11, alpha=1,color="darkmagenta", marker='o',capsize=5, capthick=1,linestyle="none")
ax1.errorbar(0.87 ,5, xerr=0.11, alpha=1,color="darkorange", marker='o',capsize=5, capthick=1,linestyle="none")


plt.axvline(1,color="k",linestyle="--")


y_labels = plt.yticks()[1]

label_to_change_1 = y_labels[0] 
label_to_change_1.set_color('darkred')
label_to_change_1.set_weight('bold')

label_to_change_2 = y_labels[1] 
label_to_change_2.set_color('navy')
label_to_change_2.set_weight('bold')

label_to_change_2 = y_labels[2] 
label_to_change_2.set_color('darkgreen')
label_to_change_2.set_weight('bold')

label_to_change_2 = y_labels[3] 
label_to_change_2.set_color('darkmagenta')
label_to_change_2.set_weight('bold')

label_to_change_3 = y_labels[4] 
label_to_change_3.set_color('darkorange')
label_to_change_3.set_weight('bold')

#plt.savefig('AL.pdf')
plt.show()
