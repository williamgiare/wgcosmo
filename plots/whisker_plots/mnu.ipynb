# %%
### Show plots inline, and load main getdist plot module and samples class
from __future__ import print_function
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import sys, os
sys.path.insert(0,os.path.realpath(os.path.join(os.getcwd(),'..')))
from getdist import plots, loadMCSamples, MCSamples
import getdist
# use this *after* importing getdist if you want to use interactive plots
# %matplotlib notebook
import matplotlib.pyplot as plt
import IPython
print('GetDist Version: %s, Matplotlib version: %s'%(getdist.__version__, plt.matplotlib.__version__))
# matplotlib 2 may not work very well without usetex on, can uncomment
# plt.rcParams['text.usetex']=True
from matplotlib import rc
import seaborn as sns
from scipy.constants import c
import numpy as np
# Out:
# GetDist Version: 1.4.1, Matplotlib version: 3.7.0

# %%
plt.rcParams["axes.edgecolor"] = "0.15"
plt.rcParams["axes.linewidth"]  = "1.5"
plt.rcParams["ytick.labelsize"]  = "17"
plt.rcParams["xtick.labelsize"]  = "17"
plt.rcParams["axes.titlesize"]  = "17"
plt.rcParams["figure.autolayout"] = True
plt.rcParams["figure.figsize"] = [10,12]



ax1 = plt.subplot(111)


ax1.set_xlabel(r'$\sum m_{\nu}$ [eV]',fontsize = 17)
ax1.grid(linewidth=0.1)

ax1.set_ylim(1.3,11.8)

ax1.set_xlim(0.01,10)

ax1.set_xscale("log")

ax1.set_yticks([])

ax1.set_xticks([0.06, 0.5, 1, 2,3,5,10])
ax1.set_xticklabels([0.06, 0.5, 1, 2,3,5,10])


#Most constraing limit
ax1.text(y=1.6, x=0.015, c="b", s=r'Most constraining Limit', size=10)

ax1.errorbar(0,1.5,xerr=0.0866, alpha=1,color="b", marker='None',capsize=5, capthick=3,linestyle="none",linewidth=3)
ax1.text(y=1.48,x=0.095, c="b", s=r'$\sum m_{\nu}<0.0866$ eV (Planck+BAO+SN)', size=8)


#Planck Based limits
ax1.text(y=2.4, x=0.015, c="r", s=r'Planck Based Limits ($\Lambda$CDM)', size=10)

ax1.errorbar(0,2,xerr=0.26, alpha=1,color="r", marker='None',capsize=5, capthick=3,linestyle="none",linewidth=3)
ax1.text(y=1.98,x=0.3, c="r", s=r'$\sum m_{\nu}<0.26$ eV (Planck TT TE EE + lowE)', size=8)
ax1.errorbar(0,2.15,xerr=0.24, alpha=1,color="r", marker='None',capsize=5, capthick=3,linestyle="none",linewidth=3)
ax1.text(y=2.13,x=0.29, c="r", s=r'$\sum m_{\nu}<0.24$ eV (Planck TT TE EE + lowE + lensing)', size=8)
ax1.errorbar(0,2.30,xerr=0.12, alpha=1,color="r", marker='None',capsize=5, capthick=3,linestyle="none",linewidth=3)
ax1.text(y=2.28, x=0.14, c="r", s=r'$\sum m_{\nu}<0.12$ eV (Planck TT TE EE + lowE + lensing + BAO)', size=8)

#ACT Based limits
ax1.text(y=3.4, x=0.015, c="darkgreen", s=r'ACT Based Limits ($\Lambda$CDM)', size=10)

ax1.errorbar(0,3,xerr=1.47, alpha=1,color="darkgreen", marker='None',capsize=5, capthick=3,linestyle="none",linewidth=3)
ax1.text(y=2.98,x=1.6, c="darkgreen", s=r'$\sum m_{\nu}<1.47$ eV (ACT)',size=8)
ax1.errorbar(0,3.15,xerr=1.2, alpha=1,color="darkgreen", marker='None',capsize=5, capthick=3,linestyle="none",linewidth=3)
ax1.text(y=3.13,x=1.25, c="darkgreen", s=r'$\sum m_{\nu}<1.2$ eV (ACT+WMAP)',size=8)
ax1.errorbar(0,3.30,xerr=0.19, alpha=1,color="darkgreen", marker='None',capsize=5, capthick=3,linestyle="none",linewidth=3)
ax1.text(y=3.28,x=0.22, c="darkgreen", s=r'$\sum m_{\nu}<0.16$ eV (ACT+WMAP+BAO)',size=8)

#SPT Based limits
ax1.text(y=4.4, x=0.015, c="darkblue", s=r'SPT Based Limits ($\Lambda$CDM)', size=10)

ax1.errorbar(0,4,xerr=0.74, alpha=1,color="darkblue", marker='None',capsize=5, capthick=3,linestyle="none",linewidth=3)
ax1.text(y=3.98,x=0.8, c="darkblue", s=r'$\sum m_{\nu}<0.74$ eV (SPT+WMAP)',size=8)
ax1.errorbar(0,4.15,xerr=0.37, alpha=1,color="darkblue", marker='None',capsize=5, capthick=3,linestyle="none",linewidth=3)
ax1.text(y=4.13,x=0.4, c="darkblue", s=r'$\sum m_{\nu}<0.37$ eV (SPT+WMAP+Planck lensing)',size=8)
ax1.errorbar(0,4.30,xerr=0.197, alpha=1,color="darkblue", marker='None',capsize=5, capthick=3,linestyle="none",linewidth=3)
ax1.text(y=4.28,x=0.21, c="darkblue", s=r'$\sum m_{\nu}<0.197$ eV (SPT+WMAP+BAO+SN)',size=8)

#Lensing Based Limits
ax1.text(y=5.4, x=0.015, c="Purple", s=r'Late-time (lensing-based) Limits ($\Lambda$CDM)', size=10)

ax1.errorbar(0,5,xerr=1.42, alpha=1,color="Purple", marker='None',capsize=5, capthick=3,linestyle="none",linewidth=3)
ax1.text(y=4.98,x=1.49, c="Purple", s=r'$\sum m_{\nu}<1.42$ eV (ACT-DR6+Planck-lensing)',size=8)
ax1.errorbar(0,5.15,xerr=0.527, alpha=1,color="Purple", marker='None',capsize=5, capthick=3,linestyle="none",linewidth=3)
ax1.text(y=5.13,x=0.55, c="Purple", s=r'$\sum m_{\nu}<0.53$ eV (ACT-DR6+Planck-lensing+BAO)',size=8)
ax1.errorbar(0,5.30,xerr=0.490, alpha=1,color="Purple", marker='None',capsize=5, capthick=3,linestyle="none",linewidth=3)
ax1.text(y=5.28,x=0.51, c="Purple", s=r'$\sum m_{\nu}<0.49$ eV (ACT-DR6+Planck-lensing+BAO+SN)',size=8)

#Axion Based Limits
ax1.text(y=6.4, x=0.015, c="k", s=r'Joint Limits on Neutrinos & QCD Axions', size=10)

ax1.errorbar(0,6,xerr=0.55, alpha=1,color="k", marker='None',capsize=5, capthick=3,linestyle="none",linewidth=3)
ax1.text(y=5.98,x=0.59, c="k", s=r'$\sum m_{\nu}<0.55$ eV and $m_a<1.62$ eV (ACT-CMB+BBN+BAO)',size=8)
ax1.errorbar(0,6.15,xerr=0.43, alpha=1,color="k", marker='None',capsize=5, capthick=3,linestyle="none",linewidth=3)
ax1.text(y=6.13,x=0.45, c="k", s=r'$\sum m_{\nu}<0.43$ eV and $m_a<1.11$ eV (ACT-DR6+Planck-lensing+BAO+SN)',size=8)
ax1.errorbar(0,6.30,xerr=0.16, alpha=1,color="k", marker='None',capsize=5, capthick=3,linestyle="none",linewidth=3)
ax1.text(y=6.28,x=0.18, c="k", s=r'$\sum m_{\nu}<0.16$ eV and $m_a<0.28$ eV (Planck CMB + BBN + BAO)',size=8)

#Limits in extensions
ax1.text(y=7.4, x=0.015, c="k", s=r'Joint Limits on Neutrinos & $N_{\rm eff}$', size=10)
ax1.errorbar(0,7,xerr=0.236, alpha=1,color="k", marker='None',capsize=5, capthick=3,linestyle="none",linewidth=3)
ax1.text(y=6.98,x=0.25, c="k", s=r'$\sum m_{\nu}<0.24$ eV and $N_{\rm eff}=3.20 \pm 0.31$ (SPT+WMAP+BAO+SN) ',size=8)
ax1.errorbar(0,7.15,xerr=0.155, alpha=1,color="k", marker='None',capsize=5, capthick=3,linestyle="none",linewidth=3)
ax1.text(y=7.13,x=0.17, c="k", s=r'$\sum m_{\nu}<0.155$ eV and $N_{\rm eff}= 2.78 \pm 0.25$ (ACT+WMAP+BAO+SN) ',size=8)
ax1.errorbar(0,7.30,xerr=0.0968, alpha=1,color="k", marker='None',capsize=5, capthick=3,linestyle="none",linewidth=3)
ax1.text(y=7.28,x=0.1, c="k", s=r'$\sum m_{\nu}<0.0968$ eV and $N_{\rm eff}=  3.06 \pm 0.17$ (Planck+BAO+SN) ',size=8)

ax1.text(y=8.4, x=0.015, c="k", s=r'Joint Limits on Neutrinos & $\Omega_k$', size=10)
ax1.errorbar(0,8,xerr=0.271, alpha=1,color="k", marker='None',capsize=5, capthick=3,linestyle="none",linewidth=3)
ax1.text(y=7.98,x=0.285, c="k", s=r'$\sum m_{\nu}<0.27$ eV and $\Omega_k=0.0027 \pm 0.0032$ (ACT+WMAP+BAO+SN) ',size=8)
ax1.errorbar(0,8.15,xerr=0.264, alpha=1,color="k", marker='None',capsize=5, capthick=3,linestyle="none",linewidth=3)
ax1.text(y=8.13,x=0.27, c="k", s=r'$\sum m_{\nu}<0.26$ eV and $\Omega_k=0.0013 \pm 0.0030$ (SPT+WMAP+BAO+SN) ',size=8)
ax1.errorbar(0,8.30,xerr=0.111, alpha=1,color="k", marker='None',capsize=5, capthick=3,linestyle="none",linewidth=3)
ax1.text(y=8.28,x=0.12, c="k", s=r'$\sum m_{\nu}<0.11$ eV and $\Omega_k=0.0009 \pm 0.0019$ (Planck+BAO+SN) ',size=8)


ax1.text(y=9.4, x=0.015, c="k", s=r'Joint Limits on Neutrinos & $w$', size=10)
ax1.errorbar(0,9,xerr=0.259, alpha=1,color="k", marker='None',capsize=5, capthick=3,linestyle="none",linewidth=3)
ax1.text(y=8.98,x=0.27, c="k", s=r'$\sum m_{\nu}<0.26$ eV and $w=−1.024 \pm 0.037$ (SPT+WMAP+BAO+SN) ',size=8)
ax1.errorbar(0,9.15,xerr=0.244, alpha=1,color="k", marker='None',capsize=5, capthick=3,linestyle="none",linewidth=3)
ax1.text(y=9.13,x=0.25, c="k", s=r'$\sum m_{\nu}<0.24$ eV and $w=−1.036 \pm 0.037$ (ACT+WMAP+BAO+SN) ',size=8)
ax1.errorbar(0,9.30,xerr=0.139, alpha=1,color="k", marker='None',capsize=5, capthick=3,linestyle="none",linewidth=3)
ax1.text(y=9.28,x=0.145, c="k", s=r'$\sum m_{\nu}<0.14$ eV and $w=−1.046 \pm 0.033$ (Planck+BAO+SN) ',size=8)

ax1.text(y=10.4, x=0.015, c="k", s=r'Joint Limits on Neutrinos & $\alpha_s$', size=10)
ax1.errorbar(0,10,xerr=0.215, alpha=1,color="k", marker='None',capsize=5, capthick=3,linestyle="none",linewidth=3)
ax1.text(y=9.98,x=0.23, c="k", s=r'$\sum m_{\nu}<0.22$ eV and $\alpha_s=0.0054 ± 0.0092$ (SPT+WMAP+BAO+SN) ',size=8)
ax1.errorbar(0,10.15,xerr=0.196, alpha=1,color="k", marker='None',capsize=5, capthick=3,linestyle="none",linewidth=3)
ax1.text(y=10.13,x=0.205, c="k", s=r'$\sum m_{\nu}<0.20$ eV and $\alpha_s=0.0117 ± 0.0076$ (ACT+WMAP+BAO+SN) ',size=8)
ax1.errorbar(0,10.30,xerr=0.0908, alpha=1,color="k", marker='None',capsize=5, capthick=3,linestyle="none",linewidth=3)
ax1.text(y=10.28,x=0.1, c="k", s=r'$\sum m_{\nu}<0.0908$ eV and $\alpha_s=-0.0044 ± 0.0066$ (Planck+BAO+SN) ',size=8)

ax1.text(y=11.4, x=0.015, c="k", s=r'Joint Limits on Neutrinos & $A_L$', size=10)
ax1.errorbar(0,11,xerr=0.184, alpha=1,color="k", marker='None',capsize=5, capthick=3,linestyle="none",linewidth=3)
ax1.text(y=10.98,x=0.19, c="k", s=r'$\sum m_{\nu}<0.184$ eV and $A_L=1.00\pm0.08$ (ACT+WMAP+BAO+SN) ',size=8)
ax1.errorbar(0,11.15,xerr=0.176, alpha=1,color="k", marker='None',capsize=5, capthick=3,linestyle="none",linewidth=3)
ax1.text(y=11.13,x=0.19, c="k", s=r'$\sum m_{\nu}<0.176$ eV and $A_L=0.916\pm0.074$ (SPT+WMAP+BAO+SN) ',size=8)
ax1.errorbar(0,11.30,xerr=0.166, alpha=1,color="k", marker='None',capsize=5, capthick=3,linestyle="none",linewidth=3)
ax1.text(y=11.28,x=0.18, c="k", s=r'$\sum m_{\nu}<0.166$ eV and $A_L=1.071 \pm 0.040$ (Planck+BAO+SN) ',size=8)

ax1.axvline(x=0.0866, c='b', ls='--', alpha=0.3)
ax1.axvline(x=0.06, c='k', ls='--', alpha=0.3)
ax1.axvline(x=0.1, c='k', ls='--', alpha=0.3)
plt.savefig('mnu.pdf')
#plt.show()

# %%
plt.rcParams["axes.edgecolor"] = "0.15"
plt.rcParams["axes.linewidth"]  = "1.5"
plt.rcParams["ytick.labelsize"]  = "17"
plt.rcParams["xtick.labelsize"]  = "17"
plt.rcParams["axes.titlesize"]  = "17"
plt.rcParams["figure.autolayout"] = True
plt.rcParams["figure.figsize"] = [10,15]



ax1 = plt.subplot(111)


ax1.set_xlabel(r'$\sum m_{\nu}$ [eV]',fontsize = 17)
ax1.grid(linewidth=0.1)

ax1.set_ylim(1.3,11.8)

ax1.set_xlim(0.01,10)

ax1.set_xscale("log")

ax1.set_yticks([])

ax1.set_xticks([0.06, 0.5, 1, 2,3,5,10])
ax1.set_xticklabels([0.06, 0.5, 1, 2,3,5,10])


#Most constraing limit
ax1.text(y=1.6, x=0.015, c="k", s=r'Most constraining Limit', size=10)

ax1.errorbar(0,1.5,xerr=0.0866, alpha=1,color="k", marker='None',capsize=5, capthick=3,linestyle="none",linewidth=3)
ax1.text(y=1.48,x=0.095, c="k", s=r'$\sum m_{\nu}<0.0866$ eV (Planck+BAO+SN)', size=8)


#Planck Based limits
ax1.text(y=2.4, x=0.015, c="k", s=r'Planck Based Limits ($\Lambda$CDM)', size=10)

ax1.errorbar(0,2,xerr=0.26, alpha=1,color="k", marker='None',capsize=5, capthick=3,linestyle="none",linewidth=3)
ax1.text(y=1.98,x=0.3, c="k", s=r'$\sum m_{\nu}<0.26$ eV (Planck TT TE EE + lowE)', size=8)
ax1.errorbar(0,2.15,xerr=0.24, alpha=1,color="k", marker='None',capsize=5, capthick=3,linestyle="none",linewidth=3)
ax1.text(y=2.13,x=0.29, c="k", s=r'$\sum m_{\nu}<0.24$ eV (Planck TT TE EE + lowE + lensing)', size=8)
ax1.errorbar(0,2.30,xerr=0.12, alpha=1,color="k", marker='None',capsize=5, capthick=3,linestyle="none",linewidth=3)
ax1.text(y=2.28, x=0.14, c="k", s=r'$\sum m_{\nu}<0.12$ eV (Planck TT TE EE + lowE + lensing + BAO)', size=8)

#ACT Based limits
ax1.text(y=3.4, x=0.015, c="k", s=r'ACT Based Limits ($\Lambda$CDM)', size=10)

ax1.errorbar(0,3,xerr=1.47, alpha=1,color="k", marker='None',capsize=5, capthick=3,linestyle="none",linewidth=3)
ax1.text(y=2.98,x=1.6, c="k", s=r'$\sum m_{\nu}<1.47$ eV (ACT)',size=8)
ax1.errorbar(0,3.15,xerr=1.2, alpha=1,color="k", marker='None',capsize=5, capthick=3,linestyle="none",linewidth=3)
ax1.text(y=3.13,x=1.25, c="k", s=r'$\sum m_{\nu}<1.2$ eV (ACT+WMAP)',size=8)
ax1.errorbar(0,3.30,xerr=0.19, alpha=1,color="k", marker='None',capsize=5, capthick=3,linestyle="none",linewidth=3)
ax1.text(y=3.28,x=0.22, c="k", s=r'$\sum m_{\nu}<0.16$ eV (ACT+WMAP+BAO)',size=8)

#SPT Based limits
ax1.text(y=4.4, x=0.015, c="k", s=r'SPT Based Limits ($\Lambda$CDM)', size=10)

ax1.errorbar(0,4,xerr=0.74, alpha=1,color="k", marker='None',capsize=5, capthick=3,linestyle="none",linewidth=3)
ax1.text(y=3.98,x=0.8, c="k", s=r'$\sum m_{\nu}<0.74$ eV (SPT+WMAP)',size=8)
ax1.errorbar(0,4.15,xerr=0.37, alpha=1,color="k", marker='None',capsize=5, capthick=3,linestyle="none",linewidth=3)
ax1.text(y=4.13,x=0.4, c="k", s=r'$\sum m_{\nu}<0.37$ eV (SPT+WMAP+Planck lensing)',size=8)
ax1.errorbar(0,4.30,xerr=0.197, alpha=1,color="k", marker='None',capsize=5, capthick=3,linestyle="none",linewidth=3)
ax1.text(y=4.28,x=0.21, c="k", s=r'$\sum m_{\nu}<0.197$ eV (SPT+WMAP+BAO+SN)',size=8)

#Lensing Based Limits
ax1.text(y=5.4, x=0.015, c="k", s=r'Late-time (lensing-based) Limits ($\Lambda$CDM)', size=10)

ax1.errorbar(0,5,xerr=1.42, alpha=1,color="k", marker='None',capsize=5, capthick=3,linestyle="none",linewidth=3)
ax1.text(y=4.98,x=1.49, c="k", s=r'$\sum m_{\nu}<1.42$ eV (ACT-DR6+Planck-lensing)',size=8)
ax1.errorbar(0,5.15,xerr=0.527, alpha=1,color="k", marker='None',capsize=5, capthick=3,linestyle="none",linewidth=3)
ax1.text(y=5.13,x=0.55, c="k", s=r'$\sum m_{\nu}<0.53$ eV (ACT-DR6+Planck-lensing+BAO)',size=8)
ax1.errorbar(0,5.30,xerr=0.490, alpha=1,color="k", marker='None',capsize=5, capthick=3,linestyle="none",linewidth=3)
ax1.text(y=5.28,x=0.51, c="k", s=r'$\sum m_{\nu}<0.49$ eV (ACT-DR6+Planck-lensing+BAO+SN)',size=8)

#Axion Based Limits
ax1.text(y=6.4, x=0.015, c="k", s=r'Joint Limits on Neutrinos & QCD Axions', size=10)

ax1.errorbar(0,6,xerr=0.55, alpha=1,color="k", marker='None',capsize=5, capthick=3,linestyle="none",linewidth=3)
ax1.text(y=5.98,x=0.59, c="k", s=r'$\sum m_{\nu}<0.55$ eV and $m_a<1.62$ eV (ACT-CMB+BBN+BAO)',size=8)
ax1.errorbar(0,6.15,xerr=0.43, alpha=1,color="k", marker='None',capsize=5, capthick=3,linestyle="none",linewidth=3)
ax1.text(y=6.13,x=0.45, c="k", s=r'$\sum m_{\nu}<0.43$ eV and $m_a<1.11$ eV (ACT-DR6+Planck-lensing+BAO+SN)',size=8)
ax1.errorbar(0,6.30,xerr=0.16, alpha=1,color="k", marker='None',capsize=5, capthick=3,linestyle="none",linewidth=3)
ax1.text(y=6.28,x=0.18, c="k", s=r'$\sum m_{\nu}<0.16$ eV and $m_a<0.28$ eV (Planck CMB + BBN + BAO)',size=8)

#Limits in extensions
ax1.text(y=7.4, x=0.015, c="k", s=r'Joint Limits on Neutrinos & $N_{\rm eff}$', size=10)
ax1.errorbar(0,7,xerr=0.236, alpha=1,color="k", marker='None',capsize=5, capthick=3,linestyle="none",linewidth=3)
ax1.text(y=6.98,x=0.25, c="k", s=r'$\sum m_{\nu}<0.24$ eV and $N_{\rm eff}=3.20 \pm 0.31$ (SPT+WMAP+BAO+SN) ',size=8)
ax1.errorbar(0,7.15,xerr=0.155, alpha=1,color="k", marker='None',capsize=5, capthick=3,linestyle="none",linewidth=3)
ax1.text(y=7.13,x=0.17, c="k", s=r'$\sum m_{\nu}<0.155$ eV and $N_{\rm eff}= 2.78 \pm 0.25$ (ACT+WMAP+BAO+SN) ',size=8)
ax1.errorbar(0,7.30,xerr=0.0968, alpha=1,color="k", marker='None',capsize=5, capthick=3,linestyle="none",linewidth=3)
ax1.text(y=7.28,x=0.1, c="k", s=r'$\sum m_{\nu}<0.0968$ eV and $N_{\rm eff}=  3.06 \pm 0.17$ (Planck+BAO+SN) ',size=8)

ax1.text(y=8.4, x=0.015, c="k", s=r'Joint Limits on Neutrinos & $\Omega_k$', size=10)
ax1.errorbar(0,8,xerr=0.271, alpha=1,color="k", marker='None',capsize=5, capthick=3,linestyle="none",linewidth=3)
ax1.text(y=7.98,x=0.285, c="k", s=r'$\sum m_{\nu}<0.27$ eV and $\Omega_k=0.0027 \pm 0.0032$ (ACT+WMAP+BAO+SN) ',size=8)
ax1.errorbar(0,8.15,xerr=0.264, alpha=1,color="k", marker='None',capsize=5, capthick=3,linestyle="none",linewidth=3)
ax1.text(y=8.13,x=0.27, c="k", s=r'$\sum m_{\nu}<0.26$ eV and $\Omega_k=0.0013 \pm 0.0030$ (SPT+WMAP+BAO+SN) ',size=8)
ax1.errorbar(0,8.30,xerr=0.111, alpha=1,color="k", marker='None',capsize=5, capthick=3,linestyle="none",linewidth=3)
ax1.text(y=8.28,x=0.12, c="k", s=r'$\sum m_{\nu}<0.11$ eV and $\Omega_k=0.0009 \pm 0.0019$ (Planck+BAO+SN) ',size=8)


ax1.text(y=9.4, x=0.015, c="k", s=r'Joint Limits on Neutrinos & $w$', size=10)
ax1.errorbar(0,9,xerr=0.259, alpha=1,color="k", marker='None',capsize=5, capthick=3,linestyle="none",linewidth=3)
ax1.text(y=8.98,x=0.27, c="k", s=r'$\sum m_{\nu}<0.26$ eV and $w=−1.024 \pm 0.037$ (SPT+WMAP+BAO+SN) ',size=8)
ax1.errorbar(0,9.15,xerr=0.244, alpha=1,color="k", marker='None',capsize=5, capthick=3,linestyle="none",linewidth=3)
ax1.text(y=9.13,x=0.25, c="k", s=r'$\sum m_{\nu}<0.24$ eV and $w=−1.036 \pm 0.037$ (ACT+WMAP+BAO+SN) ',size=8)
ax1.errorbar(0,9.30,xerr=0.139, alpha=1,color="k", marker='None',capsize=5, capthick=3,linestyle="none",linewidth=3)
ax1.text(y=9.28,x=0.145, c="k", s=r'$\sum m_{\nu}<0.14$ eV and $w=−1.046 \pm 0.033$ (Planck+BAO+SN) ',size=8)

ax1.text(y=10.4, x=0.015, c="k", s=r'Joint Limits on Neutrinos & $\alpha_s$', size=10)
ax1.errorbar(0,10,xerr=0.215, alpha=1,color="k", marker='None',capsize=5, capthick=3,linestyle="none",linewidth=3)
ax1.text(y=9.98,x=0.23, c="k", s=r'$\sum m_{\nu}<0.22$ eV and $\alpha_s=0.0054 ± 0.0092$ (SPT+WMAP+BAO+SN) ',size=8)
ax1.errorbar(0,10.15,xerr=0.196, alpha=1,color="k", marker='None',capsize=5, capthick=3,linestyle="none",linewidth=3)
ax1.text(y=10.13,x=0.205, c="k", s=r'$\sum m_{\nu}<0.20$ eV and $\alpha_s=0.0117 ± 0.0076$ (ACT+WMAP+BAO+SN) ',size=8)
ax1.errorbar(0,10.30,xerr=0.0908, alpha=1,color="k", marker='None',capsize=5, capthick=3,linestyle="none",linewidth=3)
ax1.text(y=10.28,x=0.1, c="k", s=r'$\sum m_{\nu}<0.0908$ eV and $\alpha_s=-0.0044 ± 0.0066$ (Planck+BAO+SN) ',size=8)

ax1.text(y=11.4, x=0.015, c="k", s=r'Joint Limits on Neutrinos & $A_L$', size=10)
ax1.errorbar(0,11,xerr=0.184, alpha=1,color="k", marker='None',capsize=5, capthick=3,linestyle="none",linewidth=3)
ax1.text(y=10.98,x=0.19, c="k", s=r'$\sum m_{\nu}<0.184$ eV and $A_L=1.00\pm0.08$ (ACT+WMAP+BAO+SN) ',size=8)
ax1.errorbar(0,11.15,xerr=0.176, alpha=1,color="k", marker='None',capsize=5, capthick=3,linestyle="none",linewidth=3)
ax1.text(y=11.13,x=0.19, c="k", s=r'$\sum m_{\nu}<0.176$ eV and $A_L=0.916\pm0.074$ (SPT+WMAP+BAO+SN) ',size=8)
ax1.errorbar(0,11.30,xerr=0.166, alpha=1,color="k", marker='None',capsize=5, capthick=3,linestyle="none",linewidth=3)
ax1.text(y=11.28,x=0.18, c="k", s=r'$\sum m_{\nu}<0.166$ eV and $A_L=1.071 \pm 0.040$ (Planck+BAO+SN) ',size=8)

ax1.axvline(x=0.0866, c='k', ls='--', alpha=0.3)
plt.show()
